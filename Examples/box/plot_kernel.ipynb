# %%
import numpy as np
from matplotlib import pyplot as plt
from wipy.wipy_utils import utils

model_path = "model_init"
pars = ["x", "z", "rho", "vp", "vs"]

kernel_path = "OUTPUT/grad_0000"

# %%
k_par = ["grad_vp"]
# k_par = ["Hessian1_acoustic_kernel_smooth"]

kernel = utils.load_model(model_path=kernel_path, pars=k_par)

model = utils.load_model(model_path, pars)

model = model | kernel

utils.plot_model_fast(model, 0.5, k_par[0])
# Out:
# (<Figure size 1000x1000 with 2 Axes>, <Axes: >)
